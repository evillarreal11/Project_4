# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from google.colab import files

# %%
# import os

# spark_version = 'spark-3.4.2'
# os.environ['SPARK_VERSION']=spark_version

# # Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# # Set Environment Variables
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
# os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# # Start a SparkSession
# import findspark
# findspark.init()

# %%
# from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName("Project 4").getOrCreate()

# %%
import pandas as pd
from google.colab import drive

# Connect Colab to Google Drive and access dataset
drive.mount('/content/drive',force_remount=True)

path = "/content/drive/MyDrive/Project4/creditcard.csv"

creditcard_df = pd.read_csv(path, header=0, low_memory=False, sep=',')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
import joblib as jlib

# %%
import os

# %%
#!mkdir "/content/drive/My Drive/Trained Models"

# %%
os.path.exists("/content/drive/My Drive/Trained Models")
# Out:
# True

# %%
# saved_model_path = '/content/drive/My Drive/Trained Models/'
# jlib.dump(res_classifier, '/content/drive/My Drive/Trained Models/mymodel.pkl')
# jlib.dump(<model_name>, '/content/drive/My Drive/Trained Models/scale1.pkl').  # may be  standard sclale this is the output of the scaler.fit() ; don't dump this scaler = StandardScaler()
# jlib.dump(<model_name>, '/content/drive/My Drive/Trained Models/scale2.pkl'). # may be  standard sclale this is the output of the scaler.fit() ; don't dump this scaler = MixMaxScaler()<

# %%
import joblib as jlib
myModel = jlib.load("/content/drive/My Drive/Trained Models/mymodel.pkl")
# myNewModel = jlib.load("/content/drive/My Drive/Trained Models/mynewmodel.pkl")
myNewResModel = jlib.load("/content/drive/My Drive/Trained Models/mynewmodelv2.pkl")

# %%
def make_pred(X_input):
  # perform same scaling / onehot encode as when you trained the model
  feature_cols = ['Time', 'V1',	'V2',	'V3',	'V4',	'V5', 'V6',	'V7',	'V8',	'V9',	'V10',	'V11', 'V12',	'V13',	'V14',	'V15', 'V16',	'V17',	'V18',	'V19', 'V20', 'V21',	'V22',	'V23',	'V24',	'V25',	'V26',	'V27',	'V28', 'Amount']
  X_raw_input_arr = [0.0, -1.3598071336738,-0.0727811733098497, 2.53634673796914, 1.37815522427443,-0.338320769942518, 0.462387777762292, 0.239598554061257, 0.0986979012610507, 0.363786969611213, 0.0907941719789316, -0.551599533260813,-0.617800855762348, -0.991389847235408, -0.311169353699879, 1.46817697209427, -0.470400525259478, 0.207971241929242, 0.0257905801985591,  0.403992960255733,  0.251412098239705, -0.018306777944153, 0.277837575558899, -0.110473910188767, 0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]
  input_df = pd.DataFrame([dict(zip(feature_cols, X_input))])

  # prediction = myModel.predict(input_df)
  y_pred_scaled = myModel.predict(input_df)
  # ISR = y_min_max_model.inverse_transform(y_pred_scaled).ravel()[0]

  # if y_true:
  #   absErr = y_true - ISR
  #   percErr =  absErr / y_true * 100
  # prediction = f"This is what I got: {input_array}"
  print(y_pred_scaled)
  return y_pred_scaled

# %%
import ipywidgets as widgets

# %%
# Create widget scales (ALL FEATURES)
Time = widgets.FloatSlider(
  value=10000.00,
  min=0.00,
  max=172792.00,
  step=50.00,
  description='Time Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
Amount = widgets.FloatSlider(
  value=10000.00,
  min=0.00,
  max=25691.16,
  step=50.00,
  description='Amount Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V1 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V1 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V2 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V2 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V3 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V3 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V4 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V4 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V5 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V5 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V6 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V6 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V7 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V7 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V8 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V8 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V9 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V9 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)

V10 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V10 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V11 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V11 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V12 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V12 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V13 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V13 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V14 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V14 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V15 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V15 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V16 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V16 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V17 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V17 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V18 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V18 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V19 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V19 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V20 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V20 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V21 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V21 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V22 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V22 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V23 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V23 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V24 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V24 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V25 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V25 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V26 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V26 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V27 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V27 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)
V28 = widgets.FloatSlider(
  value=5000.00,
  min=-113.75,
  max=120.59,
  step=10.50,
  description='V28 Label',
  disabled=False,
  continuous_update=False,
  orientation='vertical',
  readout=True,
  readout_format='.1f',
)

output_for_my_frontend = widgets.HBox([Time, Amount, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16,
                                       V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28])

def interaction(Time, Amount, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16,
                                       V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28):
  print(Amount, V1, V2)
  pred = make_pred([Time, V1,	V2,	V3,	V4,	V5, V6,	V7,	V8,	V9,	V10,	V11, V12,	V13,	V14,	V15, V16,	V17,	V18,	V19, V20, V21,	V22,	V23,	V24,	V25,	V26,	V27,	V28, Amount])
  return pred

out_puts = widgets.interactive_output(interaction, {'Time' : Time, 'V1': V1, 'V2': V2, 'V3': V3, 'V4': V4, 'V5': V5 , 'V6': V6, 'V7': V7, 'V8':V8, 'V9': V9, 'V10': V10, 'V11': V11, 'V12': V12, 'V13': V13, 'V14': V14, 'V15': V15, 'V16': V16, 'V17' : V17, 'V18': V18, 'V19': V19, 'V20': V20, 'V21': V21, 'V22': V22, 'V23': V23, 'V24': V24, 'V25': V25, 'V26': V26, 'V27': V27, 'V28': V28, 'Amount': Amount})

display(output_for_my_frontend, out_puts)
# Out:
# ...
# Output()

# %%
#Same as above but using resampled model trained on smaller dataset (dropped cols)

def make_pred(X_input):
  # perform same scaling / onehot encode as when you trained the model
  feature_cols = ['V3','V7','V10', 'V12', 'V14', 'V16',	'V17']
  X_raw_input_arr = [-1.3598071336738,-0.0727811733098497, 2.53634673796914, 1.37815522427443,-0.338320769942518, 0.462387777762292, 0.239598554061257, 0.09869790126105]
  input_df = pd.DataFrame([dict(zip(feature_cols, X_input))])

  # prediction = myModel.predict(input_df)
  y_pred_scaled = myNewResModel.predict(input_df)
  # ISR = y_min_max_model.inverse_transform(y_pred_scaled).ravel()[0]

  # if y_true:
  #   absErr = y_true - ISR
  #   percErr =  absErr / y_true * 100
  # prediction = f"This is what I got: {input_array}"
  print(y_pred_scaled)
  return y_pred_scaled

# %%
V3 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V3 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V7 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V7 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V10 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V10 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V12 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V12 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V14 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V14 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V16 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V16 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)
V17 = widgets.FloatSlider(
   value=5000.00,
   min=-113.75,
   max=120.59,
   step=10.50,
   description='V17 Label',
   disabled=False,
   continuous_update=False,
   orientation='vertical',
   readout=True,
   readout_format='.1f',
)

output_for_my_frontend = widgets.HBox([V3,V7,V10, V12, V14, V16,V17])

def interaction(V3,V7,V10, V12, V14, V16,V17):
  print(V3,V7,V10, V12, V14, V16,V17)
  pred = make_pred([V3,V7,V10, V12, V14, V16,V17])
  return pred

out_puts = widgets.interactive_output(interaction, {'V3': V3,'V7': V7,'V10': V10,'V12': V12, 'V14': V14,'V16': V16, 'V17' : V17,})

display(output_for_my_frontend, out_puts)
# Out:
# ...
# Output()
